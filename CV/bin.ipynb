# %%
load_pickle("./demo_result/no_face_group.pkl)
# Out:
#   File "<ipython-input-3-7370a4731613>", line 1
#     load_pickle("./demo_result/no_face_group.pkl)
#                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
load_pickle("./demo_result/no_face_group.pkl")
# Out:
# ./demo_result/no_face_group.pkl
# set()

# %%
import os
os.chdir("/home/yipeng/Desktop/movie_tracking/tracking")
from FeatureExtractor import FeatureExtractor as FE
modes = ["face_histogram", "face_histogram_he","face_encodding","face_encodding_he","pic_histogram"]
for mode in modes:
    fe = FE("./filter_tracking_result/", mode= mode)
# Out:
# ogress  105
# current progress  23
# current progress  8994
# current progress  467
# current progress  690
# current progress  901
# current progress  442
# current progress  1055
# current progress  4411
# current progress  287
# current progress  173
# current progress  1289
# current progress  83
# current progress  2623
# current progress  738
# current progress  128
# current progress  33
# current progress  803
# current progress  2506
# current progress  51
# current progress  2085
# current progress  1579
# current progress  635
# current progress  95
# current progress  1445
# current progress  121
# current progress  902
# current progress  3309
# current progress  1626
# current progress  878
# current progress  7917
# current progress  87
# current progress  1635
# current progress  859
# current progress  366
# current progress  186
# current progress  757
# current progress  71
# current progress  11400
# current progress  1734
# current progress  867
# ...

# %%
from utilities import *
