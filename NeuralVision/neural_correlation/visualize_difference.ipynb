# %%
import os
os.chdir("/home/yipeng/Desktop/Movie_Analysis/neural_correlation/")

# %%
from utilities import *
root_dir = "../Character_TimeStamp/"
all_files = os.listdir(root_dir)
bill = load_pickle("../Character_TimeStamp/3567.pkl")
jack = load_pickle(root_dir + "744.pkl")
# Out:
# ../Character_TimeStamp/3567.pkl
# ../Character_TimeStamp/744.pkl

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
timeline = np.zeros(74304)
bill_time = timeline
bill_time[bill] = 1
plt.subplot(2, 1, 1)
plt.plot(bill_time,label='bill')

# %%
jack_time = timeline
jack_time[jack] = 1
plt.subplot(2, 1, 2)
plt.plot(jack_time,label='jack')
plt.show()

# %%
a[10000]
# Out:
# array([[0., 1., 0.],
#        [1., 0., 0.]])

# %%
jack[100:110]
# Out:
# [16120, 16124, 16128, 16132, 16136, 16140, 16144, 16148, 16152, 16156]

# %%
bill[0:10]
# Out:
# [13796, 13800, 13804, 13808, 13812, 13816, 14016, 14020, 14024, 14028]

# %%
import numpy as np
a = np.load("/media/yipeng/toshiba/movie/Movie_Analysis/data/431/features_mat.npy")

# %%
a.shape
# Out:
# (171, 37800)

# %%
bb = (np.array(bill[0:10])/2).astype("int")
jj =  (np.array(jack[100:110])/2).astype("int")

# %%
bb
# Out:
# array([6898, 6900, 6902, 6904, 6906, 6908, 7008, 7010, 7012, 7014])

# %%
jj
# Out:
# array([8060, 8062, 8064, 8066, 8068, 8070, 8072, 8074, 8076, 8078])

# %%
start_b = 6890
end_b = 7030
a[:, start_b: end_b]
# Out:
# (171, 10)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
a.shape
# Out:
# (171, 37800)

# %%
plt.imshow(a[:, start_b: end_b])
plt.colorbar()

# %%
plt.imshow(a[:, (start_b - 100): end_b])
plt.colorbar()

# %%
start_b -100, end_b
# Out:
# (6790, 7030)

# %%
plt.figure(figsize=(15,20))
plt.imshow(a[:, 800:1040] - a[:, (start_b - 100): end_b])

plt.colorbar()

# %%
a[:, 800: 900] -

# %%
plt.imshow(a[:, 0: 400])
plt.colorbar()

# %%
from utilities import *
load_pickle("/media/yipeng/toshiba/movie/Movie_Analysis/CNN_result/CNN/441/confidence.pkl")
# Out:
# /media/yipeng/toshiba/movie/Movie_Analysis/CNN_result/CNN/441/confidence.pkl
# 25292],
#   [29796, 0.30255786, 0.90764, 123799.3972860925, 56024],
#   [25740, 0.9909172, 0.983665, 99089.39054276257, 94185],
#   [50512, 0.9376992, 0.829051, 138221.86037577235, 102432],
#   [28464, 0.013053284, 0.992277, 146919.54828947264, 138355],
#   [12752, 0.9954708, 0.998071, 201653.6876059787, 120744],
#   [42328, 0.9959679, 0.961154, 186849.88398552887, 32913],
#   [25944, 0.948684, 0.984198, 155979.8747115548, 151590],
#   [29784, 0.66824734, 0.83411, 114675.40119275829, 56355],
#   [67484, 0.46707073, 0.991855, 137820.70149468366, 106182],
#   [27332, 0.99819154, 0.990672, 142459.54312804513, 125976],
#   [57060, 0.9998059, 0.983743, 196682.37293407874, 142680],
#   [42340, 0.9965099, 0.943847, 187612.92899368066, 32960],
#   [50540, 0.9998436, 0.919055, 145274.8318503946, 102432],
#   [27732, 0.9946414, 0.9754, 133016.40060187917, 107124],
# ...
